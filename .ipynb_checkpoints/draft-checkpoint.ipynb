# %%
from quantum_badger import *

import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_formats=['svg']

# %%
# Import packages and load the data
import numpy as np
#import numpy.linalg as lin
import scipy.stats as sts
#import scipy.integrate as intgr
import scipy.optimize as opt

# %%
path = "/Users/anastasiacertkova/Desktop/Coding/data/21_13-16_06_2023"
id_ = 1
n_clicks = 11
n_sector = 8

cumulants = CumulantUtility(id_=id_, path=path)

M_0, M_1, M_2, M_3, M_4 = cumulants.import_moments()
m_0, m_1, m_2, m_3, m_4 = M_0[n_sector], M_1[n_sector], M_2[n_sector], M_3[n_sector], M_4[n_sector]

#m_0, m_1, m_2, m_3, m_4 =   0.014507613075891563, 5.055314024840053, 0.9840516181860579, -0.1005988155139903, -0.2730550697710896
# 5.055314024840053	0.9840516181860579	-0.1005988155139903	-0.2730550697710896	
#pts = np.random.normal(m_1, m_2, 1000)

# %%
m_0, m_1, m_2, m_3, m_4
# Out:
# (0.014190624465653395,
#  3.989879627711271,
#  0.4742132078571135,
#  -0.03163998334839846,
#  -0.13001081749553123)

# %%
p_vals = [-5.2754406679732705e-19,
 2.8482398872286304e-09,
 5.863458526385258e-06,
 9.941300340869214e-05,
 0.00042700875763206124,
 0.0007455575765970043,
 0.0004980205787828885,
 0.0001252882294094231]



x_vals = [x for x in range(len(p_vals))]

# %%
# inspired by https://notes.quantecon.org/submission/5b3b1856b9eab00015b89f90

def guess_fun(x, *args):
    
    # if cutoff == 'None':
    #     prob_notcut = 1.0
    # else:
    #     prob_notcut = sts.norm.cdf(cutoff, loc=mu, scale=sigma)
    
    for m in args:
        m = args

    if len(m) == 3:
        
        pdf_vals = m[0] *(1/(m[2] * np.sqrt(2 * np.pi)))*(
                     np.exp( - (x - m[1])**2 / (2 * m[2]**2)) 
                  ) 
        
    if len(m) == 4: 
        
        pdf_vals = m[0] *(1/(m[2] * np.sqrt(2 * np.pi)))*(
                     np.exp( - (x - m[1])**2 / (2 * m[2]**2)) 
                   * np.exp(+ m[3]*(x - m[1])**3/(3*m[2]**3))
                  ) 
        
    if len(m) == 5: 
        
        pdf_vals = m[0] *(1/(m[2] * np.sqrt(2 * np.pi)))*(
                     np.exp( - (x - m[1])**2 / (2 * m[2]**2)) 
                   * np.exp(+ m[3]*(x - m[1])**3/(3*m[2]**3))
                   * np.exp(+ m[4]*(x - m[1])**4/(8*m[2]**4))
                  
                ) 
            
                   #/prob_notcut)
    
    return pdf_vals

def model_moments(cutoff, *args):
    
    for m in args:
        m = args
        
    if len(m) == 3:
        
        s0 = 0
        s1 = 0
        s2 = 0
    
    
        for x in np.arange(cutoff):

            s0 +=  guess_fun(x, cutoff, m[0], m[1], m[2], m[3], m[4])
            s1 +=  guess_fun(x, cutoff, m[0], m[1], m[2], m[3], m[4]) * x
            s2 +=  guess_fun(x, cutoff, m[0], m[1], m[2], m[3], m[4]) * x**2

        m0_model = s0
        m1_model = s1/s0
        m2_model = s2/s0 - m1_model**2
        
        model_moms = m0_model, m1_model, m2_model

    if len(m) == 4:
        
        s0 = 0
        s1 = 0
        s2 = 0
        s3 = 0
    
    
        for x in np.arange(cutoff):

            s0 +=  guess_fun(x, m[0], m[1], m[2], m[3], m[4])
            s1 +=  guess_fun(x, m[0], m[1], m[2], m[3], m[4]) * x
            s2 +=  guess_fun(x, m[0], m[1], m[2], m[3], m[4]) * x**2
            s3 +=  guess_fun(x, m[0], m[1], m[2], m[3], m[4]) * x**3

        m0_model = s0
        m1_model = s1/s0
        m2_model = s2/s0 - m1_model**2
        m3_model = s3/s0 - 3*m2_model*m1_model - m1_model**3
        
        model_moms = m0_model, m1_model, m2_model, m3_model
        
    if len(m) == 5:
        
        s0 = 0
        s1 = 0
        s2 = 0
        s3 = 0
        s4 = 0
    
    
        for x in np.arange(cutoff):

            s0 +=  guess_fun(x, m[0], m[1], m[2], m[3], m[4])
            s1 +=  guess_fun(x, m[0], m[1], m[2], m[3], m[4]) * x
            s2 +=  guess_fun(x, m[0], m[1], m[2], m[3], m[4]) * x**2
            s3 +=  guess_fun(x, m[0], m[1], m[2], m[3], m[4]) * x**3
            s4 +=  guess_fun(x, m[0], m[1], m[2], m[3], m[4]) * x**4

        m0_model = s0
        m1_model = s1/s0
        m2_model = s2/s0 - m1_model**2
        m3_model = s3/s0 - 3*m2_model*m1_model - m1_model**3
        m4_model = s4/s0 - 4*m3_model*m1_model - 3*m2_model**2 - 6*m2_model*m1_model**2 - m1_model**4
        
        model_moms = m0_model, m1_model, m2_model, m3_model, m4_model
    
    
    return model_moms


def err_vec(cutoff, *args, simple):
    
    for m in args:
        m = args
    
    # !!!!!! 
    m_data = np.array([m_0, m_1, m_2, m_3, m_4])
    # !!!!!!
        
    if len(m) == 3: 
        m0_data, m1_data, m2_data = m_data[0], m_data[1], m_data[2]
        moms_data = np.array([[m0_data], [m1_data], [m2_data]])
        
        m0_model, m1_model, m2_model = model_moments(cutoff, m[0], m[1], m[2])
        moms_model = np.array([[m0_model],[m1_model], [m2_model]])
        
    if len(m) == 4: 
        m0_data, m1_data, m2_data, m3_data = m_data[0], m_data[1], m_data[2], m_data[3]
        moms_data = np.array([[m0_data], [m1_data], [m2_data],[m3_data]])
        
        m0_model, m1_model, m2_model, m3_model = model_moments(cutoff, m[0], m[1], m[2], m[3])
        moms_model = np.array([[m0_model],[m1_model], [m2_model], [m3_model]])
    
    if len(m) == 5: 
        m0_data, m1_data, m2_data, m3_data, m4_data = m_data[0], m_data[1], m_data[2], m_data[3], m_data[4]
        moms_data = np.array([[m0_data], [m1_data], [m2_data],[m3_data], [m4_data]])

        m0_model, m1_model, m2_model, m3_model, m4_model = model_moments(cutoff, m[0], m[1], m[2], m[3], m[4])
        moms_model = np.array([[m0_model],[m1_model], [m2_model], [m3_model], [m4_model]])
    
    if simple:
        err_vec = moms_model - moms_data
    else:
        err_vec = (moms_model - moms_data) / moms_data
    
    return err_vec


def criterion(params, *args):
    
    cutoff, W = args
    simple=False

    
    if len(params) == 3:
        m0, m1, m2 = params
        err = err_vec(cutoff, m0, m1, m2, simple=simple)
    
    if len(params) == 4:
        m0, m1, m2, m3 = params
        err = err_vec(cutoff, m0, m1, m2, m3, simple=simple)
        
    if len(params) == 5:
        m0, m1, m2, m3, m4 = params
        err = err_vec(cutoff, m0, m1, m2, m3, m4, simple=simple)
    
    
    crit_val = np.dot(np.dot(err.T, W), err) 
    
    return crit_val

def GMM(params_init, cutoff):
    
    simple = False

    W_hat = np.eye(len(params_init)) # ? because we don't have data -  only moments - we don't need to optimize this ?  
    gmm_args = (cutoff, W_hat) #(pts, cutoff, W_hat)

    results = opt.minimize(criterion, params_init, args=(gmm_args),
                           method='L-BFGS-B') #bounds=((1e-10, None), (1e-10, None)))
    
    return results.x

# %%
m1 = m_1
m2 = m_2
m3 = m_3
m4 = m_4
m0 = m_0

cutoff = 14
simple = False

params_init = np.array([m0, m1, m2, m3, m4])

m0_GMM, m1_GMM, m2_GMM, m3_GMM, m4_GMM = GMM(params_init, cutoff)

print('m0_GMM=', m0_GMM, 'm1_GMM=', m1_GMM, ' m2_GMM=', m2_GMM, ' m3_GMM=', m3_GMM, ' m4_GMM=', m4_GMM)
# Out:
# m0_GMM= 0.03658554103997339 m1_GMM= 4.841678640135775  m2_GMM= -0.9955341066842419  m3_GMM= 0.44376207029574405  m4_GMM= -0.48725147546127323

# %%
m0_model, m1_model, m2_model, m3_model, m4_model = model_moments(cutoff, m0_GMM, m1_GMM, m2_GMM, m3_GMM, m4_GMM)
err1 = err_vec(cutoff, m0_GMM, m1_GMM, m2_GMM, m3_GMM, m4_GMM, simple=simple).reshape(len(params_init),)

print('m0 of model:', m0_model, 'm1 of model:', m1_model, ',  m2 of model:', m2_model, ',  m3 of model:', m3_model, ',  m4 of model:', m4_model )
print("True m0:", m_0, "True m1:", m_1, ",  True m2:", m_2, ",  True m3:", m_3, ",  True m4:", m_4 )
print("Param 0:",  m0_GMM, "Param 1:",  m1_GMM, ",  Param 2:", m2_GMM, ",  Param 3:", m3_GMM,  ",  Param 4:", m4_GMM)
print('Error vector:', err1)
#results
# Out:
# m0 of model: -0.034144964245325315 m1 of model: 4.635029014429236 ,  m2 of model: 0.7730582401044686 ,  m3 of model: -0.13354909499307155 ,  m4 of model: -0.23710597443886172
# True m0: 0.014190624465653395 True m1: 3.989879627711271 ,  True m2: 0.4742132078571135 ,  True m3: -0.03163998334839846 ,  True m4: -0.13001081749553123
# Param 0: 0.03658554103997339 Param 1: 4.841678640135775 ,  Param 2: -0.9955341066842419 ,  Param 3: 0.44376207029574405 ,  Param 4: -0.48725147546127323
# Error vector: [-3.40616361  0.16169645  0.63019129  3.2208965   0.82374035]

# %%
#0.005852211847875202	5.105499696114283	0.6978221101823973	-0.035497770842955204

# %%
# Plot the histogram of the data
# %matplotlib inline


#dist_pts = np.linspace(1, len(p_vals)-1, len(p_vals)-1)

dist_pts = np.linspace(0,cutoff, 100)
plt.plot(dist_pts, guess_fun(dist_pts, m0_GMM, m1_GMM, m2_GMM, m3_GMM, m4_GMM),
         linewidth=2, color='k');

# %%
norm = 6.032828581420843#*60

plt.plot(
        range(len(p_vals)),
        p_vals,
        '-' )
plt.plot(dist_pts, guess_fun(dist_pts, m0_GMM, m1_GMM, m2_GMM, m3_GMM, m4_GMM)/norm,
         linewidth=2, color='k')
plt.yscale('log')
plt.ylim(10**(-11), 10**(-1))
plt.xlabel("Number of clicks", fontsize=12)
plt.ylabel("Probability mass function", fontsize=12)
plt.title("PMF for 10 sector and 10-mode GBS device", fontsize=11);

# %%
cutoff = 8
dist_pts = np.linspace(0,cutoff, 100)

test_cum = [0.116327393514674, 2.533458538367629, 0.705216354256578, 0.22196265477612612,-0.47113411260860333]
# [0.24810600044823986, 1.8876877571059212, 0.09969820302224042, -0.07730354536730033, 0.04005981300555561]
#test_cum = [0.5551081333585043, 1.80953030337605e-11, 7.15165704431365e-11, 2.834723566952392e-10, 1.126118309677458e-09]


plt.plot(dist_pts, guess_fun(dist_pts, test_cum[0], test_cum[1], test_cum[2], test_cum[3], test_cum[4]),
         linewidth=2, color='k')
plt.yscale('log')
plt.ylim(10**(-11), 2)
plt.xlabel("Number of clicks", fontsize=12)
plt.ylabel("Probability mass function", fontsize=12)
plt.title("PMF for 10 sector and 10-mode GBS device", fontsize=11);

# %%
def import_cumulants(id_, path):
    file_name = f"/output/Cumulants_{id_}.dat" 
    data = np.genfromtxt(path + file_name, skip_header=1)
    
    sectors = list(map(int, data[:,0]))
    
    A_2 = data[:,1]
    Mu1_2 = data[:,2]
    Mu2_2 = data[:,3]

    A_3 = data[:,4]
    Mu1_3 = data[:,5]
    Mu2_3 = data[:,6]
    Mu3_3 = data[:,7]


    A_4 = data[:,8]
    Mu1_4 = data[:,9]
    Mu2_4 = data[:,10]
    Mu3_4 = data[:, 11]
    Mu4_4 = data[:, 12]

    return sectors, A_2, Mu1_2, Mu2_2,  A_3, Mu1_3, Mu2_3, Mu3_3,  A_4, Mu1_4, Mu2_4, Mu3_4, Mu4_4
    

sectors, A_2, Mu1_2, Mu2_2,  A_3, Mu1_3, Mu2_3, Mu3_3,  A_4, Mu1_4, Mu2_4, Mu3_4, Mu4_4 = import_cumulants(id_, path)

# %%
plt.plot(sectors, [ guess_fun(k, A_4[k], Mu1_4[k], Mu2_4[k], Mu3_4[k], Mu4_4[k]) for k in sectors] ,
         linewidth=2)
plt.yscale('log')
#plt.ylim(10**(-11), 10**(-1))
plt.xlabel("Sector Number", fontsize=12)
plt.ylabel("Probability mass function", fontsize=12);
# plt.title("PMF for 10 sector and 10-mode GBS device", fontsize=11);

# %%
n_clicks = 10
n_sector = 10

plt.plot(range(n_clicks),
         [guess_fun(n, A_4[n_sector], Mu1_4[n_sector], Mu2_4[n_sector], Mu3_4[n_sector], Mu4_4[n_sector]) for n in range(n_clicks)],
         linewidth=2
        )
plt.yscale('log')
#plt.ylim(10**(-11), 10**(-1))
plt.xlabel("Number of clicks", fontsize=12)
plt.ylabel("Probability mass function", fontsize=12);
# plt.title("PMF for 10 sector and 10-mode GBS device", fontsize=11);

# %% [markdown]
# ## Test samples
#
# ### HOG test
# ### Bayesian Test
# ### Correlation Test
#
# ---
# ### Heavy Output Generation rate
#
# The Heavy Output Generation (HOG) rate was introduced as a convenient way to compare samples from the Boson Sampling experiment and the exact distribution with minimum of computational resources. It is given as
#
# \begin{equation*}
# \begin{gathered}
# r_{HOG} (n) = \frac{P(S^{exp}_n)}{P(S^{exp}_n) + P(S^{adv}_n)}
# \end{gathered}
# \end{equation*}
#
# where $n$ is a sample number in a bunch of experimental samples $\{S^{exp}\}$, $P(S_n)$ are the exact calculated probabilities of a samples $S_n$, ${S^{adv}}$ are samples from an adversary classical algorithm. Usually, the HOG rate dependence is given for a fixed number of photon events (clicked threshold detectors or a number of detected photons for photon number resolved detectors) and  it equals to $1$ if the experimental samples $\{S^{exp}\}$ is rather from the actual probability distribution then the adversary (the last is, for example, the thermal states hypothesis as shown in figure below)
#
#
# <img src="images/HOG_test_from_experiment.jpg" alt="Drawing" style="width: 700px;"/>
#
# *figure S26 is from Supplementary Materials for Zhong, Han-Sen, et al. "Quantum computational advantage using photons." Science 370.6523 (2020): 1460-1463.*

# %%
def HOG_rate(experimental_samples, mockup_samples, M):
    
    """Returns a value of Heavy Output Generation rate 
    for target samples (experimental_samples) and from
    adversary samples (mockup_samples)."""
    r = 0 
    batch_size = len(experimental_samples)
    
    for i in range(batch_size):
        
        r += (
            prob_exact(experimental_samples[i], M)/
            (
                 prob_exact(experimental_samples[i], M) +
                 prob_exact(mockup_samples[i], M)
            ) / batch_size
        )
    
    return r

# exp_samples = np.copy(samples) 
# adv_samples = np.copy(uniform_samples)  

# res_forw = []
# res_back = []

# for i in range(len(exp_samples)):
#     res_forw.append(HOG_rate(exp_samples, adv_samples,i, M))
#     res_back.append(HOG_rate(adv_samples, exp_samples,i, M))
    
# # Plot the HOG rate test 

# plt.plot(res_forw, '.', label = 'gaussian boson sampling')
# plt.plot(res_back, '.', label = 'uniform sampling' )
# plt.legend(prop={"size": 13}, loc="center")
# plt.xlabel("N", fontsize=15)
# plt.ylabel("HOG rate", fontsize=15)
# plt.title("Title")
# plt.show()

# %%
from concurrent.futures import ThreadPoolExecutor
from math import factorial

class PermutationCalculator():
    def __init__(self, input_list):
        
        self.items = input_list

    def calculate(self):
        if self.items is None or len(self.items) == 0:
            return []
        length = len(self.items)
        currentPosition = length - 1
        totalItem = factorial(length)
        
        currentResult = [[] for _ in range(totalItem)]
        previousResult = [[] for _ in range(totalItem)]
        
        # Add last item to the previousResult list
        previousResult[0] = [self.items[currentPosition]]
        while currentPosition > 0:
            currentResult.clear()
            for item in previousResult:
                currentResult.extend(self.add_item(item, self.items[currentPosition - 1]))
            if currentPosition - 1 > 0:
                previousResult.clear()
                previousResult.extend(currentResult)
            currentPosition -= 1
        return currentResult

    def add_item(self, currentItem, newItem):
        result = []
        pos = 0
        while pos <= len(currentItem):
            item = []
            i = 0
            j = 0
            while j < len(currentItem) + 1:
                if j == pos:
                    item.append(newItem)
                else:
                    item.append(currentItem[i])
                    i += 1
                j += 1
            result.append(item)
            pos += 1
        return result

    def calculate_parallel(self):
        
        if self.items is None or len(self.items) == 0:
            return []
        
        length = len(self.items)
        currentPosition = length - 1
        totalItem = factorial(length)
        currentResult = [[] for _ in range(totalItem)]
        previousResult = [[] for _ in range(totalItem)]
        taskLength = 1000
        previousResult[0] = [self.items[currentPosition]]
        with ThreadPoolExecutor() as executor:
            
            while currentPosition > 0:
                currentResult.clear()
                count = len(previousResult)
                numTask = count // taskLength
                if count % taskLength != 0:
                    numTask += 1
                tasks = []
                startTask = 0
                position = currentPosition
                taskInd = 0
                while taskInd < numTask:
                    end = startTask + taskLength
                    if end > len(previousResult):
                        end = len(previousResult)
                    tasks.append(executor.submit(self.run_task, previousResult[startTask:end], self.items[position - 1]))
                    startTask += taskLength
                    taskInd += 1
                for task in tasks:
                    currentResult.extend(task.result())
                if currentPosition - 1 > 0:
                    previousResult.clear()
                    previousResult.extend(currentResult)
                currentPosition -= 1
                
        return currentResult

    def run_task(self, prev_result, new_item):
        result = []
        for item in prev_result:
            result.extend(self.add_item(item, new_item))
        return result

# %% [markdown]
# <p align="right">
# <img src="images/qb_image_2.png" alt="Drawing" style="width: 300px;"/>
# <p align="right">
#
# # Project Overview
# ---
# **Quantum Badger** is a python module that solves Gaussian Boson Sampling problem with threshold detection. The main focus of this project is to demonstrate and validate the method, proposed by the [A.S. Popova and A.N. Rubtsov](https://arxiv.org/pdf/2106.01445.pdf). At the current stage, this module is designed to compute probabilities of samples rather than generate samples from a distribution. We believe that our module could be valuable for testing the output of GBS devices and serving as a benchmark for other software.
#
# # Installation
# ---
#
# To use the Quantum Budger on your local machine you need to download the repository and to have `Python 3` and the `g++` compiler installed.
#
# ## Codes and Resources Used
#
# * **Editor**: To run `demo.ipynb` file you need to install [Jupyter](https://jupyter.org/) enviroment. We used Jupyter Lab.
#
# * **Python version**: 3.9.13
#
# ## Python Packages Used
#
# To reproduce the current project, you must the following Python libraries:
#
# **General Purpose**: `shutil`, `subprocess`
#
# **Data Manipulation**: `pandas`, `datetime`
#
# **Modelling**: `math`, `random`, `scipy`, `numpy`
#
# **Validation**: `strawberryfields`, `thewalrus`
#
# **Visualization**: `matplotlib`
#
# ## Data
#
# All necessary data to reproduce basic functionality is included in the `/data` directory of the repository.
#
# Each time when you initiate simulation all input and output data is generated in the folder with the current date. The stucture of the generated data will be the following
#
# ```
# ├── data
# │   ├── min_hour-day_month_year
# │   │   ├── input
# │   │   │   ├── samples_ids.dat
# │   │   │   ├── Submatrix_0.dat
# │   │   │   ├── ...
# │   │   │   ├── Submatrix_max_id.dat
# │   │   ├── output
# │   │   │   ├── samples_probabilities.csv
# │   │   │   ├── Cumulants_0.dat
# │   │   │   ├── Moments_0.dat
# │   │   │   ├── Minors_0-1_0.dat
# │   │   │   ├── Minors_2_0.dat
# │   │   │   ├── Minors_3_0.dat
# │   │   │   ├── Minors_4_0.dat
# │   │   │   ├── Result_0.dat
# │   │   │   ├── ...
# │   │   │   ├── Cumulants_max_id.dat
# │   │   │   ├── Moments_max_id.dat
# │   │   │   ├── Minors_0-1_max_id.dat
# │   │   │   ├── Minors_2_max_id.dat
# │   │   │   ├── Minors_3_max_id.dat
# │   │   │   ├── Minors_4_max_id.dat
# │   │   │   └── Result_max_id.dat
# │   │   ├── matrix_U.dat
# │   │   ├── parameters_of_interferometer.dat
# │   │   ├── initial_state.dat
# │   │   ├── GBS_matrix.dat
# │   │   └── samples.dat
#
# ```
#
# To use your own interferometer matrix, you need to replace `data/min_hour-day_month_year/matrix_U.dat`  file.
#
# # Usage
# ---
# One can find the possible use cases of the **Quantum Badger** module in `demo.ipynb`.
#
# It is possible to use our module in two ways: to simulate your GBS device or to investigate how our method performs in general. For simulation, you need to specify the parameters of the setup and obtain samples. After this, you can compute approximate probabilities and evaluate the results using four metrics: **Relative Weighted Error**, **Total Variation Distance**, **Fidelity**, and **Cross Entropy**.
#
#
#
# **Note**
#
# `function?` or `help(function)` gives all information you could need about the method.
#
# You also can use `start_up.py` file to run a basic protocol, which requires user input in a terminal.
#
#
# # Results and Evaluation
# ---
#
# Because we are developing algorithm for computing probabilities and do not generate sample, we cannot compare our results with a device output directly. But it is possible to evaluate the performance, at least, in two ways:
#
# * Compare the probabilities of samples for an ensemble of slightly different interferometers
#
#
# * Compare the frequency of occurrence of samples of small mid-sized GBS devices and the probabilities for these samples, computed with our method (we suppose here that a large part of output samples should have large probability);
#
#
#
# # Future work
# ---
#
# Potential future work include:
#
# * Considering devices with photon losses;
#
# * Using Neural Networks for inverse moment problem, instead of the General method of moments;
#
# * Implementation of the Markov Chain Monte Carlo sampling using the approximate evaluation of probabilities, developed here.
#
# # Acknowledgments
#
# ---
#
# We appreciate the Xanadu team for the free and open-source libraries that enabled us to benchmark our method.
#
# # Support
#
# Please, don't hesitate to share your suggestions, comments or critics with the authors and send it to ppva.nastya@proton.me.
#
# # Licence
# ---
# For this github repository, the [Apache 2.0](https://www.apache.org/licenses/LICENSE-2.0) is used.

# %%
p = [0.7, 0.3]
q = [0.2, 0.8]

print(sum([p[i]*q[i] for i in range(len(p))])/(sum([p**2 for p in p])*sum([q**2 for q in q]))**0.5)
# Out:
# 0.6050832675335579

# %% [markdown]
# ---
# ### Performance of the algorithm
#
# #### The worst case: exact computation of probabilities for all basis states

# %%
# Gives exponential time growth 
import time

time_in_sec = []
n_modes = 15

for n in range (4, n_modes, 2):
    # Generate a random matrix with appropriate size 
    M, U = choose_default_device(n, r, path=None)
    
    start_time = time.perf_counter()

    # Obtain all possible samples for theshold detection
    all_permutations = threshold_basis_set(n)

    # Calculate probabilities for all possible samples 
    probabilities_exact = []

    for s in all_permutations:
        probabilities_exact.append(prob_exact(s, M))
        
    time_in_sec.append(time.perf_counter() - start_time)

# %%
plt.loglog([n for n in range (4, n_modes, 2)], time_in_sec)
plt.xlabel("Number of modes")
plt.ylabel("Time")
plt.title("Log-Log Plot: Brute Force GBS with threshold detectors");

# %%
# All states of threshold detectors computation:  

time_in_sec = []
n_modes = 24

for n in range (4, n_modes, 2):
    
    start_time = time.perf_counter()

    # Obtain all possible samples for theshold detection
    all_permutations = threshold_basis_set(n)
    
    time_in_sec.append(time.perf_counter() - start_time)

# %%
plt.loglog([n for n in range (4, n_modes, 2)], time_in_sec)
plt.xlabel("Number of modes")
plt.ylabel("Time")
plt.title("Log-Log Plot: Find all states (recursion)");

# %% [markdown]
# Just for comparison, we also plot an uniform sampling

# %%
time_in_sec = []
n_modes = 500
batch_size = 10 

for n in range (4, n_modes, 2):
    
    start_time = time.perf_counter()

    samples = uniform_sampling_tr(batch_size, n, 2*n)
    
    time_in_sec.append(time.perf_counter() - start_time)

# %%
plt.loglog([n for n in range (4, n_modes, 2)] , time_in_sec, '-')
plt.xlabel("Number of clicked detectors")
plt.ylabel("Time")
plt.title("Log-Log Plot: Uniform Sampling");
